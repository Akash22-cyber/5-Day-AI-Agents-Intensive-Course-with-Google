# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > Quantum computing advancements are poised to revolutionize AI by significantly enhancing its performance, enabling it to solve currently intractable problems, and offering more efficient and sustainable solutions. These advancements are expected to improve AI's capabilities in areas like drug discovery, materials science, and cybersecurity, while also leading to more energy-efficient AI models. Although widespread commercial adoption is still likely over a decade away, the field is progressing rapidly with active investment and development.

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Outline:
#
# **Headline:** Unleash the Power of Collaboration: How Multi-Agent Systems Can Revolutionize Your Software Development
#
# **Introduction Hook:** Imagine a world where your software development isn't a solitary battle, but a synchronized symphony of intelligent agents working together. That's the promise of Multi-Agent Systems (MAS), and if you're a software developer looking for an edge, you need to understand what they can do for you.
#
# **Main Sections:**
#
# **1. Enhanced Problem Solving & Complexity Management**
#     *   Break down complex problems into smaller, manageable tasks assigned to specialized agents.
#     *   Leverage the collective intelligence of multiple agents to find more robust and creative solutions.
#     *   Facilitate distributed decision-making, allowing for parallel processing and faster outcomes.
#
# **2. Improved System Robustness & Resilience**
#     *   Design systems where the failure of one agent doesn't cripple the entire application.
#     *   Enable agents to dynamically adapt to changing environments and unforeseen circumstances.
#     *   Implement fault-tolerance through redundant agents or fallback mechanisms.
#
# **3. Streamlined Development & Maintenance**
#     *   Promote modularity and reusability by creating self-contained, independent agents.
#     *   Simplify debugging and testing by isolating issues to specific agents.
#     *   Enable easier updates and modifications as individual agents can be changed without impacting the whole system.
#
# **4. Accelerated Innovation & Emerging Possibilities**
#     *   Explore new paradigms in software design, moving beyond traditional monolithic architectures.
#     *   Build more sophisticated and adaptive AI-powered applications, from intelligent assistants to autonomous systems.
#     *   Open doors to creating self-healing, self-optimizing, and self-managing software.
#
# **Conclusion:** Multi-Agent Systems aren't just a theoretical concept; they are a practical and powerful approach that can fundamentally transform how software is built and how it performs. By embracing MAS, developers can unlock new levels of efficiency, resilience, and intelligence, paving the way for the next generation of innovative software solutions.
# WriterAgent > ## Unleash the Power of Collaboration: How Multi-Agent Systems Can Revolutionize Your Software Development
#
# Imagine a world where your software development isn't a solitary battle, but a synchronized symphony of intelligent agents working together. That's the promise of Multi-Agent Systems (MAS), and if you're a software developer looking for an edge, you need to understand what they can do for you.
#
# MAS allows you to break down dauntingly complex problems into smaller, manageable tasks, each handled by a specialized agent. This distributed decision-making and parallel processing capability leads to faster, more robust, and often more creative solutions than traditional approaches.
#
# Beyond problem-solving, MAS significantly boosts system robustness. By designing systems where the failure of one agent doesn't cascade into a total system collapse, you build resilience. Agents can dynamically adapt to unforeseen circumstances, and fault tolerance becomes an inherent feature through redundancy.
#
# The benefits extend to the development lifecycle itself. MAS promotes modularity and reusability, making your codebase cleaner and easier to manage. Debugging and testing become simpler as issues can often be isolated to specific agents. Updates and modifications are less disruptive, as individual agents can be refined without impacting the entire application.
#
# Finally, MAS is a gateway to accelerated innovation. It opens doors to new design paradigms beyond monolithic structures, enabling the creation of sophisticated AI-powered applications, from intelligent assistants to entirely autonomous systems. Imagine building software that can truly self-heal, self-optimize, and self-manage.
#
# Multi-Agent Systems are more than just a concept; they're a practical, powerful approach set to redefine software development and performance. Embrace MAS, and unlock new levels of efficiency, resilience, and intelligence for your next groundbreaking project.
# EditorAgent > ## Unleash the Power of Collaboration: How Multi-Agent Systems Can Revolutionize Your Software Development
#
# Imagine your software development process transforming from a solitary struggle into a synchronized symphony of intelligent agents working in harmony. This isn't science fiction; it's the reality offered by Multi-Agent Systems (MAS). For software developers seeking a competitive edge, understanding MAS is no longer optional – it's essential.
#
# MAS empowers you to dismantle overwhelmingly complex problems into smaller, more manageable tasks. Each of these tasks is then delegated to a specialized agent, fostering distributed decision-making and parallel processing. This approach consistently yields solutions that are not only faster and more robust but often more innovative than those achieved through traditional methodologies.
#
# Beyond enhanced problem-solving, MAS dramatically improves system resilience. By architecting systems where the failure of a single agent doesn't trigger a catastrophic collapse, you build inherent robustness. Agents possess the remarkable ability to dynamically adapt to unforeseen circumstances, and fault tolerance becomes a built-in feature, often achieved through agent redundancy.
#
# The advantages ripple through the entire development lifecycle. MAS champions modularity and reusability, leading to cleaner, more manageable codebases. Debugging and testing become significantly simpler as issues can typically be pinpointed to specific agents. Furthermore, updates and modifications are far less disruptive; individual agents can be refined or replaced without impacting the integrity of the entire application.
#
# Ultimately, MAS serves as a catalyst for accelerated innovation. It liberates us from the constraints of monolithic structures, opening pathways to entirely new design paradigms. This enables the creation of sophisticated, AI-powered applications, ranging from intelligent personal assistants to fully autonomous systems. Envision software that can genuinely self-heal, self-optimize, and self-manage its operations.
#
# Multi-Agent Systems are far more than an abstract concept; they represent a practical, potent methodology poised to redefine software development and performance. By embracing MAS, you can unlock unprecedented levels of efficiency, resilience, and intelligence for your next visionary project.

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# TechResearcher > **AI/ML Trends: Key Developments and Impact**
#
# **1. Generative AI's Expansion:** Generative AI is moving beyond text and images to create complex multimedia content, new proteins, and materials. Companies like Google (Imagen, Muse) are at the forefront, with the generative AI market projected for significant growth. This trend promises accelerated drug discovery, personalized medicine, and breakthroughs in materials science.
#
# **2. Agentic AI and Autonomy:** AI is evolving from reactive tools to proactive, autonomous agents capable of independent decision-making and action. These agents can manage complex tasks, from environmental monitoring to automating office work. Major tech companies like Microsoft (Copilot) are developing AI companions that simplify daily life and work.
#
# **3. Ethical and Explainable AI:** As AI integrates more deeply, there's a growing demand for transparency, accountability, and fairness. Companies are focusing on developing secure, unbiased, and explainable AI models to build trust and meet regulatory requirements, especially in sensitive sectors like healthcare and finance.
# HealthResearcher > ## Health Research Briefing: Key Medical Breakthroughs
#
# **1. AI-Driven Drug Discovery:**
# Artificial intelligence is revolutionizing drug development by accelerating target identification, optimizing drug candidates, and predicting toxicity. This significantly reduces the lengthy timelines and high costs associated with traditional methods.
# *   **Practical Application:** Faster development of new treatments for various diseases.
# *   **Estimated Timeline:** Ongoing, with increasing integration and impact expected within the next 3-5 years.
#
# **2. CRISPR Gene Editing Advancements:**
# CRISPR technology continues to evolve, enabling precise DNA modifications for treating genetic disorders. Recent approvals for sickle cell disease and beta-thalassemia mark significant milestones.
# *   **Practical Application:** Potential cures for inherited diseases, advancements in cancer therapy.
# *   **Estimated Timeline:** Clinical applications are expanding, with broader accessibility anticipated in 5-10 years.
#
# **3. Novel Alzheimer's Treatments:**
# New therapies targeting amyloid plaques, like lecanemab and donanemab, are showing promise in slowing cognitive decline. AI-driven diagnostics and blood tests are also improving early detection.
# *   **Practical Application:** Improved management and potential slowing of Alzheimer's progression.
# *   **Estimated Timeline:** Increased availability and refinement of current treatments within 2-5 years, with ongoing research for more effective therapies.
# FinanceResearcher > **Tech:** The escalating AI race is drawing comparisons to the Cold War, with both the US and China heavily investing in AI development. China aims to integrate AI across its economy by 2030, while US tech companies are pushing the boundaries of generative AI. This intense competition is driving innovation and significant spending in the AI sector.
#
# **Health:** Egypt and India are strengthening cooperation in healthcare, focusing on pharmaceutical industry expertise and joint investment opportunities. Discussions include vaccine production, oncology drugs, and biopharmaceuticals, with a goal of technology transfer. Meanwhile, NHS providers are addressing a significant cyber attack where stolen data has been published online, impacting patient and staff information.
#
# **Finance:** Global markets reacted positively to progress on ending the US government shutdown, boosting risk sentiment. However, lingering US-China trade tensions and anticipation of economic data releases are creating market uncertainty. Central banks' monetary policy remains a key focus, with expectations of interest rate cuts influencing gold prices.
#
# ---
#
# **Fintech Trends:**
#
# 1.  **Embedded Finance:** Seamlessly integrating financial services into non-financial platforms (e.g., e-commerce checkout, ride-sharing apps).
#     *   **Market Implications:** Increased customer convenience, new revenue streams for tech companies, and broader financial inclusion.
#     *   **Future Outlook:** Widespread adoption across industries, blurring lines between tech and finance.
#
# 2.  **AI and Machine Learning in Financial Services:** Leveraging AI for fraud detection, personalized recommendations, algorithmic trading, and risk assessment.
#     *   **Market Implications:** Enhanced operational efficiency, improved customer experience, and more sophisticated financial products.
#     *   **Future Outlook:** Deeper integration leading to hyper-personalized financial advice and automated decision-making.
#
# 3.  **Decentralized Finance (DeFi):** Utilizing blockchain technology to create open, permissionless financial systems, reducing reliance on traditional intermediaries.
#     *   **Market Implications:** Potential for lower transaction costs, increased transparency, and greater access to financial services globally.
#     *   **Future Outlook:** Continued evolution and regulation, with potential to disrupt traditional banking and investment models.
# AggregatorAgent > ## Executive Summary: Tech, Health, and Finance Briefing
#
# The accelerating AI race, particularly in generative and agentic AI, is a dominant theme across all sectors. This technological leap is profoundly impacting healthcare through **AI-driven drug discovery** and diagnostics, promising faster treatment development for diseases like Alzheimer's and enabling breakthroughs in genetic therapies via CRISPR. The trend towards **autonomous AI agents** is also poised to streamline operations and simplify daily life.
#
# Simultaneously, the integration of AI in financial services, from **embedded finance** to sophisticated risk assessment and fraud detection, is enhancing efficiency and customer experience. However, the rapid advancement of AI necessitates a strong focus on **ethical and explainable AI** to ensure transparency, fairness, and regulatory compliance, especially critical in sensitive areas like healthcare and finance.
#
# While global markets show volatility influenced by geopolitical tensions and monetary policy, the underlying innovation driven by AI and advanced biotechnologies like CRISPR presents significant opportunities. International cooperation in healthcare, as seen between Egypt and India, and the ongoing competition in AI development between the US and China, highlight the global scale of these transformative trends. The primary takeaway is the pervasive and accelerating influence of AI, coupled with the increasing importance of ethical considerations and the potential for significant advancements in health and finance.

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias polished the lantern's immense lens, its beam a familiar sweep across the inky sea. For thirty years, the lighthouse had been his world, a stoic sentinel against the storms. Tonight, however, was different. A peculiar light flickered near the old sea chest, a chest he hadn't opened in years. Curiosity tugged, a rare emotion for the stoic keeper. He lifted the heavy lid, revealing not the expected moth-eaten charts, but a rolled parchment, pulsing with an ethereal blue glow. Unfurling it, Elias gasped. Lines of light, like ancient constellations, traced an unknown ocean, dotted with islands no chart had ever marked. The map hummed softly in his calloused hands, a silent invitation to a world beyond the horizon.
# CriticAgent > - The pacing feels a bit rushed. While the discovery is exciting, Elias's immediate acceptance and intrigue with the map could be expanded upon. Consider adding a moment of hesitation or disbelief before he fully embraces its potential.
# - The description of the map is evocative, but adding a sensory detail beyond sight and sound could further immerse the reader. For example, does the parchment feel different, or does it emit a subtle scent?
# - Elias is described as "stoic," but his reaction to the map is immediate curiosity. Consider showing, rather than telling, his stoicism through his actions or internal thoughts prior to the discovery to create a stronger contrast.
# RefinerAgent > Elias ran a calloused thumb over the cool, smooth glass of the lantern, his world a predictable cycle of polished brass and the rhythmic sweep of light across the inky sea. Thirty years he'd kept this vigil, a stoic sentinel against the tempestuous moods of the ocean. The sea was a harsh mistress, demanding unwavering attention, leaving little room for fanciful thoughts. His days were as ordered as the tides, his nights a testament to routine. Yet, tonight, an anomaly. A flicker, not of the lamp, but from the shadows near the old sea chest—a relic he hadn't disturbed since his predecessor had passed. A flicker of what? He approached cautiously, the familiar scent of salt and oil in the air doing little to quell a prickle of unease. Curiosity, a long-dormant emotion, stirred within him. He lifted the heavy, salt-encrusted lid. Instead of the expected mildewed charts, a rolled parchment lay nestled within. It pulsed with an ethereal blue glow, a light that seemed to breathe. Hesitantly, Elias reached for it. The parchment felt strangely cool, almost alive, beneath his touch, and it carried a faint, dry scent, like ancient dust and ozone. As he unfurled it, a soft hum vibrated through his fingers. Lines of light, reminiscent of distant constellations, blazed across an unknown ocean, charting islands that existed on no map he knew. A moment of disbelief warred with the undeniable reality before him. This was no mere chart; it was an invitation, a silent, luminous promise of a world beyond the familiar horizon. The stoic keeper, for the first time in decades, felt the sea's vastness not as a boundary, but as a beginning.
# CriticAgent > APPROVED
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
